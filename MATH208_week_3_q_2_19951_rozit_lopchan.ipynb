# %% [markdown]
# <a href="https://colab.research.google.com/github/Roz1t/Math208/blob/main/MATH208_week_3_q_2_19951_rozit_lopchan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

def calculate_mean(numbers):
    if len(numbers) == 0:
        return None
    return sum(numbers) / len(numbers)

def calculate_median(numbers):
    sorted_numbers = sorted(numbers)
    n = len(sorted_numbers)
    if n % 2 == 0:
        middle1 = sorted_numbers[n // 2 - 1]
        middle2 = sorted_numbers[n // 2]
        median = (middle1 + middle2) / 2
    else:
        median = sorted_numbers[n // 2]
    return median

def calculate_std_deviation(numbers):
    mean = calculate_mean(numbers)
    if mean is None:
        return None
    squared_diff = [(x - mean) ** 2 for x in numbers]
    variance = sum(squared_diff) / len(numbers)
    std_deviation = variance ** 0.5
    return std_deviation

random_numbers = [random.gauss(10, 0.5) for _ in range(500)]

mean = calculate_mean(random_numbers)
median = calculate_median(random_numbers)
std_deviation = calculate_std_deviation(random_numbers)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_deviation)

plt.hist(random_numbers, bins=10, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Numbers (Gaussian)')
plt.grid(True)
plt.show()
# Out:
# Mean: 9.988038098374702
# Median: 9.982431343811303
# Standard Deviation: 0.5176438504865195
